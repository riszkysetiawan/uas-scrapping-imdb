# %%
from bs4 import BeautifulSoup
import pandas as pd
import cloudscraper
import re
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.options import Options

path = "chromedriver-win32/chromedriver.exe"

chrome_options = Options()
chrome_options.add_argument("--headless")
service = Service(path)
# browser = webdriver.Chrome(options = chrome_options, service = service)
browser = webdriver.Chrome()
   
browser.get("https://www.imdb.com/")
search_box = browser.find_element("id", "suggestion-search")

search_box.clear()
search_box.send_keys("Minions")

search_btn = browser.find_element("id", "suggestion-search-button")
search_btn.click()

page = browser.page_source
soup = BeautifulSoup(page, "html.parser")

link_tag = soup.find('a', class_='ipc-metadata-list-summary-item__t')
if link_tag:
    link = link_tag['href']
    full_link = f"https://www.imdb.com{link}"
    print("Menemukan link: ", full_link)
    
    # Navigate to the movie page
    browser.get(full_link)
    
    # Get the page source and parse it with BeautifulSoup
    page = browser.page_source
    soup = BeautifulSoup(page, "html.parser")
    
    # Scrape the desired element (e.g., Top picks)
    top_picks_tag = soup.find('a', href=re.compile('/what-to-watch/top-picks'))
    if top_picks_tag:
        top_picks_link = top_picks_tag['href']
        full_top_picks_link = f"https://www.imdb.com{top_picks_link}"
        print("Menemukan Top Picks link: ", full_top_picks_link)
        
        # Navigate to the Top Picks page
        browser.get(full_top_picks_link)
        
        # Wait for the page to load
        browser.implicitly_wait(5)
        
        # Get the page source and parse it with BeautifulSoup
        page = browser.page_source
        soup = BeautifulSoup(page, "html.parser")
        
        # Scrape the movie titles and links
        movie_tags = soup.find_all('a', class_='ipc-poster-card__title ipc-poster-card__title--clamp-2 ipc-poster-card__title--clickable')
        movies = []
        for tag in movie_tags:
            title = tag.find('span', {'data-testid': 'title'}).text
            movie_link = f"https://www.imdb.com{tag['href']}"
            movies.append({"Title": title, "Link": movie_link})
            print(f"Title: {title}")
            print(f"Link: {movie_link}")
            print(f"")
        
        # Convert the list of dictionaries to a DataFrame and save as CSV
        df = pd.DataFrame(movies)
        df.to_csv('tittle.csv', index=False)
        print("CSV file tittle.csv sudah dibuat.")
    else:
        print("Top Picks link tidak ditemukan")
else:
    print("Link tidak ditemukan")
# Out:
# Menemukan link:  https://www.imdb.com/title/tt2293640/?ref_=fn_al_tt_1
# Menemukan Top Picks link:  https://www.imdb.com/what-to-watch/top-picks/?ref_=tt_tpks_sm
# Title: Despicable Me 2
# Link: https://www.imdb.com/title/tt1690953/?ref_=watch_tpks_tt_t_1_pd_tp1_pbr_ic
#
# Title: Despicable Me
# Link: https://www.imdb.com/title/tt1323594/?ref_=watch_tpks_tt_t_2_pd_tp1_pbr_ic
#
# Title: Hotel Transylvania
# Link: https://www.imdb.com/title/tt0837562/?ref_=watch_tpks_tt_t_3_pd_tp1_pbr_ic
#
# Title: The Angry Birds Movie
# Link: https://www.imdb.com/title/tt1985949/?ref_=watch_tpks_tt_t_4_pd_tp1_pbr_ic
#
# Title: Ralph Breaks the Internet
# Link: https://www.imdb.com/title/tt5848272/?ref_=watch_tpks_tt_t_5_pd_tp1_pbr_ic
#
    title = tag.find('span', {'data-testid': 'title'}).text
    movie_link = f"https://www.imdb.com{tag['href']}"
    
    # Navigate to the movie's page
    browser.get(movie_link)
    browser.implicitly_wait(5)
    movie_page = browser.page_source
    movie_soup = BeautifulSoup(movie_page, "html.parser")
    
    # Scrape box office information
    box_office = {
        "Budget": "0",
        "Gross US & Canada": "0",
        "Opening weekend US & Canada": "0",
        "Gross worldwide": "0"
    }
    box_office_tags = movie_soup.find_all('li', {'data-testid': re.compile('title-boxoffice-*')})
    for box_office_tag in box_office_tags:
        label = box_office_tag.find('span', class_='ipc-metadata-list-item__label').text.strip()
        value = box_office_tag.find('span', class_='ipc-metadata-list-item__list-content-item').text.strip()
        # Menghilangkan simbol $ dan (estimated)
        value = re.sub(r'[$, \(estimated\)]', '', value)
        if label in box_office:
            box_office[label] = value
    
    # Scrape technical specs information
    technical_specs = {
        "Runtime": "0",
        "Color": "0",
        "Sound mix": "0",
        "Aspect ratio": "0"
    }
    tech_specs_tags = movie_soup.find_all('li', {'data-testid': re.compile('title-techspec-*')})
    for tech_specs_tag in tech_specs_tags:
        label = tech_specs_tag.find('span', class_='ipc-metadata-list-item__label').text.strip()
        content_container = tech_specs_tag.find('div', class_='ipc-metadata-list-item__content-container')
        if content_container:
            value = content_container.get_text(separator=" ").strip()
            if label == "Runtime":
                parts = value.split()
                runtime_minutes = 0
                for i in range(len(parts)):
                    if 'h' in parts[i]:
                        hours = int(parts[i-1].replace('h', '')) if i > 0 else 0
                        runtime_minutes += hours * 60
                    elif 'min' in parts[i]:
                        minutes_str = parts[i-1] if i > 0 else parts[i]  # Ambil bagian sebelum "min"
                        minutes = int(minutes_str.replace('min', '')) if minutes_str.isdigit() else 0
                        runtime_minutes += minutes
                value = str(runtime_minutes)
            if label in technical_specs:
                technical_specs[label] = value

    
    # Combine the data
    movie_data = {
        "Title": title,
        **box_office,
        **technical_specs
    }
    movies_data.append(movie_data)
    
    print(f"Title: {title}")
    print(f"Box Office: {box_office}")
    print(f"Technical Specs: {technical_specs}")
    print(f"------------------------------------------")

# Buat DataFrame dari data movies_data
df = pd.DataFrame(movies_data)

# Isi nilai yang hilang dengan 0
df.fillna("0", inplace=True)

# Simpan DataFrame ke dalam file CSV dengan nama kolom yang diinginkan
df.to_csv('detailed_film.csv', index=False)

print("Data telah disimpan ke dalam file CSV dengan nama detailed_film.csv")
# Out:
# Title: Migration
# Box Office: {'Budget': '70000000', 'Gross US & Canada': '127306285', 'Opening weekend US & Canada': '12453275', 'Gross worldwide': '298614786'}
# Technical Specs: {'Runtime': '83', 'Color': 'Color', 'Sound mix': 'Dolby Digital IMAX 6-Track Dolby Atmos 12-Track Digital Sound Auro 11.1 DTS:X', 'Aspect ratio': '2.35 : 1'}
# ------------------------------------------
# Title: Trolls Band Together
# Box Office: {'Budget': '0', 'Gross US & Canada': '102996915', 'Opening weekend US & Canada': '30002525', 'Gross worldwide': '209349087'}
# Technical Specs: {'Runtime': '91', 'Color': 'Color', 'Sound mix': '12-Track Digital Sound Auro 11.1 DTS Dolby Atmos Dolby Digital', 'Aspect ratio': '2.39 : 1'}
# ------------------------------------------
# Title: Kung Fu Panda
# Box Office: {'Budget': '130000000', 'Gross US & Canada': '215771591', 'Opening weekend US & Canada': '60239130', 'Gross worldwide': '632091832'}
# Technical Specs: {'Runtime': '92', 'Color': 'Color', 'Sound mix': 'SDDS Dolby Digital DTS', 'Aspect ratio': '2.39 : 1'}
# ------------------------------------------
# Title: Despicable Me 3
# Box Office: {'Budget': '80000000', 'Gross US & Canada': '264624300', 'Opening weekend US & Canada': '72434025', 'Gross worldwide': '1034800131'}
# Technical Specs: {'Runtime': '89', 'Color': 'Color', 'Sound mix': 'SDDS Dolby Digital Auro 11.1 Dolby Surround 7.1 Dolby 12-Track Digital Sound Dolby Atmos DTS', 'Aspect ratio': '2.39 : 1'}
# ------------------------------------------
# Title: Madagascar
# Box Office: {'Budget': '75000000', 'Gross US & Canada': '193595521', 'Opening weekend US & Canada': '47224594', 'Gross worldwide': '542063846'}
# Technical Specs: {'Runtime': '86', 'Color': 'Color', 'Sound mix': 'DTS Dolby Digital SDDS', 'Aspect ratio': '1.85 : 1'}
# ------------------------------------------
# Title: Minions
# Box Office: {'Budget': '74000000', 'Gross US & Canada': '336045770', 'Opening weekend US & Canada': '115718405', 'Gross worldwide': '1159457503'}
# Technical Specs: {'Runtime': '91', 'Color': 'Color', 'Sound mix': 'Datasat SDDS Dolby Digital Dolby Atmos Auro 11.1 Dolby Surround 7.1 Dolby 12-Track Digital Sound', 'Aspect ratio': '1.85 : 1'}
# ------------------------------------------
# Title: The Angry Birds Movie 2
# Box Office: {'Budget': '65000000', 'Gross US & Canada': '41667116', 'Opening weekend US & Canada': '10354073', 'Gross worldwide': '147792047'}
# Technical Specs: {'Runtime': '97', 'Color': 'Color', 'Sound mix': 'Dolby Surround 7.1 Dolby Atmos Auro 11.1 DTS:X Dolby Digital D-Cinema 96kHz 7.1 12-Track Digital Sound', 'Aspect ratio': '1.85 : 1'}
# ------------------------------------------
# Title: The Super Mario Bros. Movie
# Box Office: {'Budget': '100000000', 'Gross US & Canada': '574934330', 'Opening weekend US & Canada': '146361865', 'Gross worldwide': '1361992475'}
# Technical Specs: {'Runtime': '92', 'Color': 'Color', 'Sound mix': 'Dolby Digital 12-Track Digital Sound Dolby Atmos IMAX 6-Track', 'Aspect ratio': '2.39 : 1'}
# ------------------------------------------
# Title: Rio
# Box Office: {'Budget': '90000000', 'Gross US & Canada': '143619809', 'Opening weekend US & Canada': '39225962', 'Gross worldwide': '483866772'}
# Technical Specs: {'Runtime': '96', 'Color': 'Color', 'Sound mix': 'Dolby Datasat SDDS Dolby Surround 7.1', 'Aspect ratio': '2.35 : 1 2.39 : 1'}
# ------------------------------------------
# Title: Inside Out
# Box Office: {'Budget': '175000000', 'Gross US & Canada': '356921711', 'Opening weekend US & Canada': '90440272', 'Gross worldwide': '858852998'}
# Technical Specs: {'Runtime': '95', 'Color': 'Color', 'Sound mix': 'Dolby Digital Datasat Dolby Atmos SDDS Dolby Surround 7.1 Auro 11.1 12-Track Digital Sound D-Cinema 48kHz Dolby Surround 7.1 D-Cinema 96kHz 7.1 D-Cinema 96kHz 5.1', 'Aspect ratio': '1.78 : 1'}
# ------------------------------------------
# Title: Vivo
# Box Office: {'Budget': '0', 'Gross US & Canada': '0', 'Opening weekend US & Canada': '0', 'Gross worldwide': '278381'}
# Technical Specs: {'Runtime': '95', 'Color': 'Color', 'Sound mix': 'Dolby Digital', 'Aspect ratio': '2.39 : 1'}
# ------------------------------------------
# Title: IF
# Box Office: {'Budget': '110000000', 'Gross US & Canada': '84299263', 'Opening weekend US & Canada': '33715801', 'Gross worldwide': '141899263'}
# Technical Specs: {'Runtime': '104', 'Color': 'Color', 'Sound mix': 'Dolby Digital D-Cinema 96kHz 7.1 Auro 11.1 Dolby Atmos 12-Track Digital Sound Dolby Surround 7.1', 'Aspect ratio': '1:1.85 DCP flat'}
# ------------------------------------------
# Title: DC League of Super-Pets
# Box Office: {'Budget': '90000000', 'Gross US & Canada': '93657117', 'Opening weekend US & Canada': '23003441', 'Gross worldwide': '207557117'}
# Technical Specs: {'Runtime': '105', 'Color': '0', 'Sound mix': 'Dolby Digital Dolby Atmos', 'Aspect ratio': '2.39:1'}
# ------------------------------------------
# Title: Garfield and Friends
# Box Office: {'Budget': '0', 'Gross US & Canada': '0', 'Opening weekend US & Canada': '0', 'Gross worldwide': '0'}
# Technical Specs: {'Runtime': '30', 'Color': 'Color', 'Sound mix': 'Mono', 'Aspect ratio': '1.33 : 1'}
# ------------------------------------------
# Title: Megamind
# Box Office: {'Budget': '130000000', 'Gross US & Canada': '148415853', 'Opening weekend US & Canada': '46016833', 'Gross worldwide': '321885765'}
# Technical Specs: {'Runtime': '95', 'Color': 'Color', 'Sound mix': 'SDDS DTS Dolby Surround 7.1', 'Aspect ratio': '2.39 : 1'}
# ------------------------------------------
# Title: Spies in Disguise
# Box Office: {'Budget': '100000000', 'Gross US & Canada': '66757013', 'Opening weekend US & Canada': '13354798', 'Gross worldwide': '171616764'}
# Technical Specs: {'Runtime': '102', 'Color': 'Color', 'Sound mix': '12-Track Digital Sound Dolby Digital Auro 11.1 Dolby Surround 7.1', 'Aspect ratio': '2.35 : 1 2.39 : 1'}
# ------------------------------------------
# Title: Knuckles
# Box Office: {'Budget': '0', 'Gross US & Canada': '0', 'Opening weekend US & Canada': '0', 'Gross worldwide': '0'}
# Technical Specs: {'Runtime': '0', 'Color': 'Color', 'Sound mix': 'Dolby Digital Dolby Atmos', 'Aspect ratio': '2.39 : 1'}
# ------------------------------------------
# Title: Kung Fu Panda 4
# Box Office: {'Budget': '85000000', 'Gross US & Canada': '193579450', 'Opening weekend US & Canada': '57989905', 'Gross worldwide': '542334019'}
# Technical Specs: {'Runtime': '94', 'Color': 'Color', 'Sound mix': 'Dolby Digital Dolby Atmos Dolby Surround 7.1 IMAX 6-Track Auro 11.1 D-Cinema 96kHz Dolby Surround 7.1 DTS:X 12-Track Digital Sound', 'Aspect ratio': '1.85 : 1 2.39 : 1'}
# ------------------------------------------
# Title: Sonic Prime
# Box Office: {'Budget': '0', 'Gross US & Canada': '0', 'Opening weekend US & Canada': '0', 'Gross worldwide': '0'}
# Technical Specs: {'Runtime': '22', 'Color': 'Color', 'Sound mix': 'Dolby Digital Dolby Atmos', 'Aspect ratio': '1.78 : 1 16:9 HD'}
# ------------------------------------------
# Title: Incredibles 2
# Box Office: {'Budget': '200000000', 'Gross US & Canada': '608581744', 'Opening weekend US & Canada': '182687905', 'Gross worldwide': '1243225667'}
# Technical Specs: {'Runtime': '118', 'Color': 'Color', 'Sound mix': 'Dolby Atmos Dolby Digital IMAX 6-Track Auro 11.1 Dolby Surround 7.1', 'Aspect ratio': '2.39 : 1'}
# ------------------------------------------
# Title: Hotel Transylvania 2
# Box Office: {'Budget': '80000000', 'Gross US & Canada': '169700110', 'Opening weekend US & Canada': '48464322', 'Gross worldwide': '475186976'}
# Technical Specs: {'Runtime': '89', 'Color': 'Color', 'Sound mix': 'Datasat Dolby Digital Dolby Surround 7.1 Dolby Atmos SDDS', 'Aspect ratio': '1.85 : 1'}
# ------------------------------------------
# Title: Leo
# Box Office: {'Budget': '0', 'Gross US & Canada': '0', 'Opening weekend US & Canada': '0', 'Gross worldwide': '0'}
# Technical Specs: {'Runtime': '102', 'Color': 'Color', 'Sound mix': 'Dolby Digital', 'Aspect ratio': '2.00 : 1'}
# ------------------------------------------
# Title: Toy Story 4
# Box Office: {'Budget': '200000000', 'Gross US & Canada': '434038008', 'Opening weekend US & Canada': '120908065', 'Gross worldwide': '1073841394'}
# Technical Specs: {'Runtime': '100', 'Color': 'Color', 'Sound mix': 'IMAX 6-Track Auro 11.1 12-Track Digital Sound Dolby Digital Dolby Surround 7.1', 'Aspect ratio': '2.39 : 1'}
# ------------------------------------------
# Title: Kung Fu Panda 2
# Box Office: {'Budget': '150000000', 'Gross US & Canada': '165249063', 'Opening weekend US & Canada': '47656302', 'Gross worldwide': '665692281'}
# Technical Specs: {'Runtime': '90', 'Color': 'Color', 'Sound mix': 'SDDS DTS Dolby Surround 7.1', 'Aspect ratio': '2.39 : 1'}
# ------------------------------------------
# Title: Toy Story 2
# Box Office: {'Budget': '90000000', 'Gross US & Canada': '245852179', 'Opening weekend US & Canada': '300163', 'Gross worldwide': '497375381'}
# Technical Specs: {'Runtime': '92', 'Color': '0', 'Sound mix': 'SDDS Dolby Digital DTS Dolby Digital EX Dolby Stereo DTS-ES D-Cinema 96kHz Dolby Surround 7.1 D-Cinema 48kHz 5.1 D-Cinema 48kHz 7.1 DTS-Stereo Spectra-Stereo', 'Aspect ratio': '0'}
# ------------------------------------------
# Title: Sonic the Hedgehog
# Box Office: {'Budget': '85000000', 'Gross US & Canada': '148974665', 'Opening weekend US & Canada': '58018348', 'Gross worldwide': '319715683'}
# Technical Specs: {'Runtime': '99', 'Color': 'Color', 'Sound mix': 'Dolby Digital Dolby Atmos Dolby Surround 7.1 Auro 11.1 D-Cinema 96kHz 7.1 DTS:X 12-Track Digital Sound', 'Aspect ratio': '2.39 : 1'}
# ------------------------------------------
# Title: Minions: The Rise of Gru
# Box Office: {'Budget': '80000000', 'Gross US & Canada': '370270765', 'Opening weekend US & Canada': '107010140', 'Gross worldwide': '940203765'}
# Technical Specs: {'Runtime': '87', 'Color': 'Color', 'Sound mix': 'Auro 11.1 SDDS Dolby Digital IMAX 6-Track Dolby Surround 7.1', 'Aspect ratio': '2.39 : 1'}
# ------------------------------------------
# Title: Hotel Transylvania
# Box Office: {'Budget': '85000000', 'Gross US & Canada': '148313048', 'Opening weekend US & Canada': '42522194', 'Gross worldwide': '358375603'}
# Technical Specs: {'Runtime': '91', 'Color': 'Color', 'Sound mix': 'SDDS Datasat Dolby Digital Dolby Atmos', 'Aspect ratio': '1.85 : 1'}
# ------------------------------------------
# Title: Sonic the Hedgehog 2
# Box Office: {'Budget': '110000000', 'Gross US & Canada': '190872904', 'Opening weekend US & Canada': '72105176', 'Gross worldwide': '405421518'}
# Technical Specs: {'Runtime': '122', 'Color': 'Color', 'Sound mix': 'Dolby Atmos Dolby Digital Auro 11.1 Dolby Surround 7.1 12-Track Digital Sound DTS:X D-Cinema 96kHz Dolby Surround 7.1', 'Aspect ratio': '2.39 : 1'}
# ------------------------------------------
# Title: Ice Age: Dawn of the Dinosaurs
# Box Office: {'Budget': '90000000', 'Gross US & Canada': '196573705', 'Opening weekend US & Canada': '41690382', 'Gross worldwide': '886686817'}
# Technical Specs: {'Runtime': '94', 'Color': 'Color', 'Sound mix': 'DTS Dolby SDDS', 'Aspect ratio': '1.85 : 1'}
# ------------------------------------------
# Title: Despicable Me
# Box Office: {'Budget': '69000000', 'Gross US & Canada': '251683815', 'Opening weekend US & Canada': '56397125', 'Gross worldwide': '543284256'}
# Technical Specs: {'Runtime': '95', 'Color': 'Color', 'Sound mix': 'DTS Dolby Digital SDDS', 'Aspect ratio': '1.85 : 1'}
# ------------------------------------------
# Title: The Lego Movie 2: The Second Part
# Box Office: {'Budget': '99000000', 'Gross US & Canada': '105956290', 'Opening weekend US & Canada': '34115335', 'Gross worldwide': '199603202'}
# Technical Specs: {'Runtime': '107', 'Color': '0', 'Sound mix': 'Dolby Atmos Dolby Digital Dolby Surround 7.1', 'Aspect ratio': '2.35 : 1 2.39 : 1'}
# ------------------------------------------
# Title: The SpongeBob Movie: Sponge Out of Water
# Box Office: {'Budget': '74000000', 'Gross US & Canada': '162994032', 'Opening weekend US & Canada': '55365012', 'Gross worldwide': '325186032'}
# Technical Specs: {'Runtime': '92', 'Color': 'Color', 'Sound mix': 'SDDS Datasat Dolby Digital Dolby Atmos Dolby Surround 7.1', 'Aspect ratio': '1.85 : 1'}
# ------------------------------------------
# Title: Despicable Me 2
# Box Office: {'Budget': '76000000', 'Gross US & Canada': '368065385', 'Opening weekend US & Canada': '83517315', 'Gross worldwide': '970766005'}
# Technical Specs: {'Runtime': '98', 'Color': 'Color', 'Sound mix': 'Dolby Digital Datasat SDDS Dolby Atmos Dolby Surround 7.1 Auro 11.1', 'Aspect ratio': '1.85 : 1'}
# ------------------------------------------
# Title: Home
# Box Office: {'Budget': '135000000', 'Gross US & Canada': '177397510', 'Opening weekend US & Canada': '52107731', 'Gross worldwide': '386041607'}
# Technical Specs: {'Runtime': '94', 'Color': 'Color', 'Sound mix': 'Dolby Digital Dolby Surround 7.1 Auro 11.1 Dolby Atmos Datasat SDDS Dolby', 'Aspect ratio': '1.85 : 1'}
# ------------------------------------------
# Title: Orion and the Dark
# Box Office: {'Budget': '0', 'Gross US & Canada': '0', 'Opening weekend US & Canada': '0', 'Gross worldwide': '0'}
# Technical Specs: {'Runtime': '93', 'Color': 'Color', 'Sound mix': 'Dolby Digital', 'Aspect ratio': '2.39:1'}
# ------------------------------------------
# Title: Next Gen
# Box Office: {'Budget': 'CN¥150000000', 'Gross US & Canada': '0', 'Opening weekend US & Canada': '0', 'Gross worldwide': '2379961'}
# Technical Specs: {'Runtime': '106', 'Color': 'Color', 'Sound mix': '0', 'Aspect ratio': '2.35 : 1'}
# ------------------------------------------
# Title: Madagascar 3: Europe's Most Wanted
# Box Office: {'Budget': '145000000', 'Gross US & Canada': '216391482', 'Opening weekend US & Canada': '60316738', 'Gross worldwide': '746921274'}
# Technical Specs: {'Runtime': '93', 'Color': 'Color', 'Sound mix': 'Datasat Dolby Digital SDDS Dolby Surround 7.1', 'Aspect ratio': '1.85 : 1'}
# ------------------------------------------
# Title: The Angry Birds Movie
# Box Office: {'Budget': '73000000', 'Gross US & Canada': '107509366', 'Opening weekend US & Canada': '38155177', 'Gross worldwide': '352333929'}
# Technical Specs: {'Runtime': '97', 'Color': 'Color', 'Sound mix': 'Dolby Atmos Dolby Surround 7.1 Dolby Digital SDDS', 'Aspect ratio': '2.35 : 1'}
# ------------------------------------------
# Title: Fairly OddParents: A New Wish
# Box Office: {'Budget': '0', 'Gross US & Canada': '0', 'Opening weekend US & Canada': '0', 'Gross worldwide': '0'}
# Technical Specs: {'Runtime': '0', 'Color': 'Color', 'Sound mix': '0', 'Aspect ratio': '16:9 HD'}
# ------------------------------------------
# Title: Hotel Transylvania 3: Summer Vacation
# Box Office: {'Budget': '80000000', 'Gross US & Canada': '167510016', 'Opening weekend US & Canada': '44076225', 'Gross worldwide': '528583774'}
# Technical Specs: {'Runtime': '97', 'Color': 'Color', 'Sound mix': 'Dolby Digital Dolby Atmos SDDS Auro 11.1', 'Aspect ratio': '1.85 : 1'}
# ------------------------------------------
# Data telah disimpan ke dalam file CSV dengan nama informasiFilm.csv

# %%
# Baca file CSV pertama
df1 = pd.read_csv('title.csv')

# Baca file CSV kedua
df2 = pd.read_csv('detailed_film.csv')

# Gabungkan kedua DataFrame berdasarkan kolom "Title"
merged_df = pd.merge(df1, df2, on='Title', how='inner')

# Simpan DataFrame hasil penggabungan ke dalam file CSV
merged_df.to_csv('merge_data_film.csv', index=False)

print("Data telah digabungkan dan disimpan dalam file CSV dengan nama merge_data_film.csv")
# Out:
# Data telah digabungkan dan disimpan dalam file CSV dengan nama IMDB_FILM_UAS.csv
